# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
item_type = data.groupby('ItemType', as_index=False).sum()[['ItemType','RetailSales','RetailTransfers', 'WarehouseSales']]
item_type = item_type[item_type['WarehouseSales']>0]

# %%
item_type.plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (10, 8)})

ax = sns.histplot(x=item_type[['RetailSales','RetailTransfers', 'WarehouseSales']], hue=item_type['ItemType'])

ax.set_title('ItemType')
ax.set(xlabel='ItemType', ylim=0.70000)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3560/3444153769.py in <module>
#       1 sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (10, 8)})
#       2
# ----> 3 ax = sns.histplot(x=item_type[['RetailSales','RetailTransfers', 'WarehouseSales']], hue=item_type['ItemType'])
#       4
#       5 ax.set_title('ItemType')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1428 ):
#    1429
# -> 1430     p = _DistributionPlotter(
#    1431         data=data,
# ...

# %%
item_type
# Out:
#       ItemType  RetailSales  RetailTransfers  WarehouseSales
# 0         BEER    209763.11        234924.44      2437617.32
# 2         KEGS         0.00             0.00        43558.00
# 3       LIQUOR    309847.85        334176.41        33173.32
# 4  NON-ALCOHOL      8109.97          9058.37         8656.72
# 7         WINE    313400.42        340710.51       433009.47

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data['mix_retail'] = data.RetailSales + data.RetailTransfers + data.WarehouseSales
supplier = data.groupby('Supplier', as_index=False)['mix_retail'].sum()
supplier.sort_values('mix_retail', ascending=False, inplace=True).nla

# %%
supplier = supplier.nlargest(10, 'mix_retail')
supplier
# Out:
#                      Supplier  mix_retail
# 184    MILLER BREWING COMPANY   646822.71
# 69              CROWN IMPORTS   636094.20
# 15         ANHEUSER BUSCH INC   583737.97
# 139              HEINEKEN USA   362740.01
# 94         E & J GALLO WINERY   218180.45
# 78   DIAGEO NORTH AMERICA INC   174877.36
# 65       CONSTELLATION BRANDS   159983.37
# 150        JIM BEAM BRANDS CO    85105.83
# 288            THE WINE GROUP    80823.98
# 38    BOSTON BEER CORPORATION    76064.12

# %%
#
sns.set(style='whitegrid')
f, ax = plt.subplots(figsize=(20, 10))

sns.set_color_codes("pastel")
sns.barplot(x='mix_retail', y='Supplier', data=supplier, label='WarehouseSales', color='b', estimator=sum)
'''sns.set_color_codes("muted")
sns.barplot(x='RetailSales', y='Supplier', data=data2, label='RetailSales', color='b', estimator=sum)'''

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0,700000), ylabel="",
       xlabel="Top 10 Supplier - Sales by Channel");

# %%
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
mean_month = data.groupby('Month', as_index=False).mean()[['Month','RetailSales','RetailTransfers', 'WarehouseSales']]
mean_month
# Out:
#    Month  RetailSales  RetailTransfers  WarehouseSales
# 0      1     5.679413         5.574833       19.072137
# 1      2     5.939247         6.050136       20.229658
# 2      4     0.000000        15.707503        0.000000
# 3      5     7.038838         7.421817       27.310548
# 4      6     7.143914         6.950396       27.839069
# 5      8     6.409991         6.584726       28.122641
# 6      9     6.757254         6.419721       22.817909
# 7     10     6.549021         6.827827       22.289367
# 8     11     6.765496         7.103699       23.348862
# 9     12     9.078241         8.353759       21.169463

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 8)})
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

#sns.set_color_codes("muted")
sns.lineplot(x=mean_month['Month'], y=mean_month['RetailSales'])
#sns.set_color_codes("muted")
sns.lineplot(x=mean_month['Month'], y=mean_month['RetailTransfers'])
#sns.set_color_codes("muted")
sns.lineplot(x=mean_month['Month'], y=mean_month['WarehouseSales'])

ax.set_title('Total Retail Sales by Item Type over time ', fontsize=20)
ax.set_xlabel('Date', fontsize= 20)
ax.set_ylabel('Retail Sales', fontsize= 20)
# Out:
# Text(0, 0.5, 'Retail Sales')

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 8)})
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 10))

sns.set_color_codes("pastel")
sns.barplot(x=mean_month['Month'], y=mean_month['RetailSales'])
sns.set_color_codes("muted")
sns.barplot(x=mean_month['Month'], y=mean_month['RetailTransfers'])
sns.set_color_codes("muted")
sns.barplot(x=mean_month['Month'], y=mean_month['WarehouseSales'])

ax.set_title('Total Retail Sales by Item Type over time ', fontsize=20)
ax.set_xlabel('Date', fontsize= 20)
ax.set_ylabel('Retail Sales', fontsize= 20)
# Out:
# Text(0, 0.5, 'Retail Sales')

# %%
mean_month.plot.bar();

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data['Date'] =data['Month'].astype('str') +'-'+ data['Year'].astype('str') 
data.Date = pd.to_datetime(data.Date)
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales  mix_retail       Date
# 0              1.0             0.0         1.0 2017-04-01
# 1              1.0             0.0         1.0 2017-04-01
# 2              8.0             0.0         8.0 2017-04-01
# ...

# %%
sub_data = data.groupby(['ItemType','Date'], as_index=False)['RetailSales'].sum()
sub_data
# Out:
#    ItemType       Date  RetailSales
# 0      BEER 2017-04-01         0.00
# 1      BEER 2017-05-01     25023.24
# 2      BEER 2017-06-01     27863.26
# 3      BEER 2017-08-01     23030.13
# 4      BEER 2017-09-01     23852.76
# ..      ...        ...          ...
# 68     WINE 2017-10-01     33108.76
# 69     WINE 2017-11-01     38275.92
# 70     WINE 2017-12-01     51492.76
# 71     WINE 2018-01-01     29792.72
# 72     WINE 2018-02-01     29409.39
#
# [73 rows x 3 columns]

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 8)})

ax = sns.lineplot(x=sub_data['Date'], y=sub_data['RetailSales'], hue=sub_data['ItemType'])

ax.set_title('Total Retail Sales by Item Type over time ', fontsize=20)
ax.set_xlabel('Date', fontsize= 20)
ax.set_ylabel('Retail Sales', fontsize= 20)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=65);
# Out:
# Text(0, 0.5, 'Retail Sales')

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 8)})

ax = sns.barplot(x=sub_data['Date'].dt.date, y=sub_data['RetailSales'], hue=sub_data['ItemType'])

ax.set_title('Total Retail Sales by Item Type over time ', fontsize=20)
ax.set_xlabel('Date', fontsize= 20)
ax.set_ylabel('Retail Sales', fontsize= 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 8)})

ax = sns.scatterplot(x=data['RetailSales'], y=data['RetailTransfers'], hue=data['ItemType'])

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
data_sub = data.iloc[: , -6:]
sns.set(context='notebook', style='darkgrid', rc={'figure.figsize': (20, 15)})
sns.pairplot(hue='ItemType', data=data_sub, palette='rocket')

# %%
data_sub
# Out:
#        ItemType  RetailSales  RetailTransfers  WarehouseSales  mix_retail  \
# 0          WINE         0.00              1.0             0.0        1.00
# 1          WINE         0.00              1.0             0.0        1.00
# 2        LIQUOR         0.00              8.0             0.0        8.00
# 3        LIQUOR         0.00              2.0             0.0        2.00
# 4          WINE         0.00              4.0             0.0        4.00
# ...         ...          ...              ...             ...         ...
# 128350     BEER        66.46             59.0           212.0      337.46
# 128351     BEER         9.08              7.0            35.0       51.08
# 128352     KEGS         0.00              0.0            32.0       32.00
# 128353      REF         0.00              0.0           -35.0      -35.00
# 128354      REF         0.00              0.0           -81.0      -81.00
#
#              Date
# 0      2017-04-01
# 1      2017-04-01
# 2      2017-04-01
# ...
