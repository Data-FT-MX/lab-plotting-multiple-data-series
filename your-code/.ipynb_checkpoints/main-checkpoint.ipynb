# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
df = data.groupby('ItemType').sum()
df = df[df['WarehouseSales'] > 0]
df.head()
# Out:
#                   Year   Month  RetailSales  RetailTransfers  WarehouseSales
# ItemType
# BEER          33132676  115830    209763.11        234924.44      2437617.32
# KEGS           7338694   27033         0.00             0.00        43558.00
# LIQUOR        57282701  197353    309847.85        334176.41        33173.32
# NON-ALCOHOL    1266826    4426      8109.97          9058.37         8656.72
# WINE         159514312  562617    313400.42        340710.51       433009.47

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 6)})

ax = df[['RetailSales', 'RetailTransfers', 'WarehouseSales']].plot.bar()
ax.set_ylabel('Count', fontsize=14)
ax.set_xlabel('Product', fontsize=14)
# Out:
# Text(0.5, 0, 'Product')

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
df = data.groupby('Supplier').sum()
df['total'] = df['WarehouseSales'] + df['RetailSales']
df = df.sort_values('total', ascending=False).head(10)
df.head()
# Out:
#                            Year  Month  RetailSales  RetailTransfers  \
# Supplier
# MILLER BREWING COMPANY  2602210   8980     35022.63         39176.67
# CROWN IMPORTS            812941   2800     26707.83         29561.67
# ANHEUSER BUSCH INC      4322888  15170     42559.14         47322.64
# HEINEKEN USA             982381   3412     20923.17         23004.25
# E & J GALLO WINERY      9418283  32124     67455.63         75129.83
#
#                         WarehouseSales      total
# Supplier
# MILLER BREWING COMPANY       572623.41  607646.04
# CROWN IMPORTS                579824.70  606532.53
# ANHEUSER BUSCH INC           493856.19  536415.33
# HEINEKEN USA                 318812.59  339735.76
# E & J GALLO WINERY            75594.99  143050.62

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 6)})

ax = df['total'].plot.barh(color='g')
ax.set_ylabel('Supplier', fontsize=12)
ax.set_xlabel('Total sales', fontsize=12);

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
df = data.groupby('Month').mean()
df.head()
# Out:
#        Year  RetailSales  RetailTransfers  WarehouseSales
# Month
# 1      2018     5.679413         5.574833       19.072137
# 2      2018     5.939247         6.050136       20.229658
# 4      2017     0.000000        15.707503        0.000000
# 5      2017     7.038838         7.421817       27.310548
# 6      2017     7.143914         6.950396       27.839069

# %%
# valores negaivos

sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 6)})

ax = df[['RetailSales', 'RetailTransfers', 'WarehouseSales']].plot()
ax.set_ylabel('Supplier', fontsize=12);

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 6)})

ax = df[['RetailSales', 'RetailTransfers', 'WarehouseSales']].plot.bar()
ax.set_ylabel('Supplier', fontsize=12)
ax.set_xlabel('Total sales', fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
df = data.copy()
df['date'] = data['Month'].astype('str') + '-' + data['Year'].astype('str')
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales       date
# 0              1.0             0.0 2017-04-01
# 1              1.0             0.0 2017-04-01
# 2              8.0             0.0 2017-04-01
# 3              2.0             0.0 2017-04-01
# ...

# %%
pivote = pd.pivot_table(
    df,
    values=['RetailSales'],
    index=['ItemType', 'date'], # La primera columna va primero y el segundo item va despues
    aggfunc={'RetailSales': 'sum'}
)

pivote = pivote.reset_index()
pivote.head()
# Out:
#   ItemType       date  RetailSales
# 0     BEER 2017-04-01         0.00
# 1     BEER 2017-05-01     25023.24
# 2     BEER 2017-06-01     27863.26
# 3     BEER 2017-08-01     23030.13
# 4     BEER 2017-09-01     23852.76

# %%
sns.set(context='notebook', style='darkgrid', rc={'figure.figsize': (15, 10)})

ax = sns.lineplot(x='date', y='RetailSales', hue='ItemType', data=pivote, palette="deep")
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Retail Sales', fontsize=14)
ax.set_title('Retail Sales for every Item', fontsize=20);

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
sns.set(context='notebook', style='darkgrid', rc={'figure.figsize': (15, 10)})

ax = sns.barplot(x=pivote['date'].dt.date, y='RetailSales', hue='ItemType', data=pivote, palette="deep")
ax.set_xlabel('Date', fontsize=14)
ax.set_ylabel('Retail Sales', fontsize=14)
ax.set_title('Retail Sales for every Item', fontsize=20)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(data=data, x='RetailSales', y='RetailTransfers', hue='ItemType');

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data, hue='ItemType', palette='magma');
